# %% [markdown]
# <a href="https://colab.research.google.com/github/Huxwell/ColabNNs/blob/main/cats_n_dogs_results_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
# plt.plot([100, 300, 500, 1000, 2000, 4000, 15000],[0.6008, 0.6693, 0.692799,  0.739, 0.8188, 0.8988, 0.9506],'--bo', label="Random crop 0.6-1.0")
# plt.plot([100, 300, 500, 1000, 2000, 4000],[0.6008, 0.6693, 0.692799,  0.739, 0.8188, 0.8988],'--bo', label="Random crop 0.6-1.0") #don't show last one full train set; just ease of reading the plot
# plt.plot([1000, 4000],[0.6646, 0.8212],'--ro', label="No random crop")
plt.plot([100,300,500,1000,2000,4000],[0.6080,0.6474,0.649,0.7226,0.76,0.8702],'--go',  label="Random crop 0.9 - 1.0")
plt.plot([100,500,1000,2000, 4000],[0.6106,0.6683,0.7372, 0.7754, 0.869],'--yo',  label="Random crop 0.9 - 1.0 + 40% bad crops")
plt.plot([100,500,1000,2000, 4000],[0.5798,0.674,0.7522, 0.8152, 0.9016],'--mo',  label="Random crop 0.9 - 1.0 + 40% bad crops as 0.7, 0.3")



plt.legend()
plt.grid()
plt.xlabel('Train set size')
plt.ylabel('Validation accuracy')
plt.show()

# %%
plt.figure(figsize=(12,10))
# plt.plot([100, 300, 500, 1000, 2000, 4000, 15000],[0.6008, 0.6693, 0.692799,  0.739, 0.8188, 0.8988, 0.9506],'--bo', label="Random crop 0.6-1.0")
# plt.plot([100, 300, 500, 1000, 2000, 4000],[0.6008, 0.6693, 0.692799,  0.739, 0.8188, 0.8988],'--bo', label="Random crop 0.6-1.0") #don't show last one full train set; just ease of reading the plot
# plt.plot([1000, 4000],[0.6646, 0.8212],'--ro', label="No random crop")
plt.plot([100, 500, 1000, 2000, 4000],[18, 11, 31, 20, 38],'--go',  label="Random crop 0.9 - 1.0")
plt.plot([100, 500, 1000, 2000, 4000],[5, 19, 32, 29, 32],'--yo',  label="Random crop 0.9 - 1.0 + 40% bad crops")
plt.plot([100, 500, 1000, 2000, 4000],[2, 29, 40, 34, 38],'--mo',  label="Random crop 0.9 - 1.0 + 40% bad crops as 0.7, 0.3")



plt.legend()
plt.grid()
plt.xlabel('Train set size')
plt.ylabel('Epochs untill best model (patience=7)')
plt.show()
